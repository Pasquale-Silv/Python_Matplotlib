# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as web

# %%
btc_usd = web.DataReader("BTC-USD", "yahoo")

print(btc_usd.head(), "\n")

print(btc_usd.shape, " ", btc_usd.size)

btc_usd["High"].plot()
plt.show()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2015-10-27  296.212006  285.007996  285.181000  293.787994  46331800.0
# 2015-10-28  306.330994  293.703003  293.703003  304.618011  50808100.0
# 2015-10-29  318.170013  301.822998  304.324005  313.855011  64495900.0
# 2015-10-30  334.169006  313.940002  313.942993  328.015015  78305000.0
# 2015-10-31  332.777008  309.251007  328.511993  314.165985  48598100.0
#
#              Adj Close
# Date
# 2015-10-27  293.787994
# 2015-10-28  304.618011
# 2015-10-29  313.855011
# 2015-10-30  328.015015
# 2015-10-31  314.165985
#
# (1824, 6)   10944

# %%
btc_eur = web.DataReader("BTC-EUR", "yahoo")

print(btc_eur.head(), "\n")

print(btc_eur.shape, " ", btc_eur.size)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2015-10-27  268.137970  257.785828  257.918976  266.329437  42001450.0
# 2015-10-28  276.372253  266.228241  266.252380  278.903137  46519044.0
# 2015-10-29  290.062927  276.445312  278.633942  285.660339  58702011.0
# 2015-10-30  303.983459  285.841766  285.740417  298.032898  71147555.0
# 2015-10-31  302.359619  280.984009  298.484467  285.449738  44156005.0
#
#              Adj Close
# Date
# 2015-10-27  266.329437
# 2015-10-28  278.903137
# 2015-10-29  285.660339
# 2015-10-30  298.032898
# 2015-10-31  285.449738
#
# (1824, 6)   10944
