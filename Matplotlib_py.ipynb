# %%
# Import the matplotlib.pyplot submodule and name it plt
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

ax.plot(btcUsd['Adj Close'])

# Call the show function to show the result
plt.show()

# %%
seattle_weather = pd.read_csv("seattle_weather.csv")
austin_weather = pd.read_csv("austin_weather.csv")
btcUsd = pd.read_csv("BTC-USD.csv", index_col=0, parse_dates=True)
ethUsd = pd.read_csv("ETH-USD.csv", index_col=0, parse_dates=True)

print("BTC/USD:\n")
print(btcUsd.head())
print(btcUsd.index)

print("\n\nETH/USD:\n")
print(ethUsd.head())
print(ethUsd.index, "\n\n")

plt.plot(btcUsd['Adj Close'])


plt.plot(ethUsd['Adj Close'])

# Call the show function
plt.show()
# Out:
# BTC/USD:
#
#                    Open          High          Low        Close    Adj Close  \
# Date
# 2019-11-01  9193.992188   9505.051758  6617.166992  7569.629883  7569.629883
# 2019-12-01  7571.616211   7743.431641  6540.049316  7193.599121  7193.599121
# 2020-01-01  7194.892090   9553.125977  6914.996094  9350.529297  9350.529297
# 2020-02-01  9346.357422  10457.626953  8492.932617  8599.508789  8599.508789
# 2020-03-01  8599.758789   9167.695313  4106.980957  6438.644531  6438.644531
#
#                    Volume
# Date
# 2019-11-01   676919523637
# 2019-12-01   633790373406
# 2020-01-01   852872174477
# 2020-02-01  1163376492755
# 2020-03-01  1290442059630
# DatetimeIndex(['2019-11-01', '2019-12-01', '2020-01-01', '2020-02-01',
#                '2020-03-01', '2020-04-01', '2020-05-01', '2020-06-01',
#                '2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01',
#                '2020-10-24'],
#               dtype='datetime64[ns]', name='Date', freq=None)
#
#
# ...

# %%
plt.plot(btcUsd['Adj Close'], color='b', marker='o', linestyle="--")

plt.plot(ethUsd['Adj Close'], color='r', marker='v', linestyle="--")

plt.show()

# %%
plt.plot(btcUsd['Adj Close'])
plt.plot(ethUsd['Adj Close'])

# Customize the x-axis label
plt.xlabel("Time")

# Customize the y-axis label
plt.ylabel("Adjusted closure")

# Add the title
plt.title("BTC Vs ETH")

# Display the figure
plt.show()

# %%
# Create a Figure and an array of subplots with 2 rows and 2 columns
fig, ax = plt.subplots(2, 2)

# Addressing the top left Axes as index 0, 0, plot month and Seattle precipitation
ax[0, 0].plot(btcUsd['Adj Close'])

# In the top right (index 0,1), plot month and Seattle temperatures
ax[0, 1].plot(seattle_weather['MLY-CLDD-BASE45'], seattle_weather['MLY-TAVG-NORMAL'])

# In the bottom left (1, 0) plot month and Austin precipitations
ax[1, 0].plot(austin_weather['MLY-CLDD-BASE45'], austin_weather['MLY-PRCP-NORMAL'])

# In the bottom right (1, 1) plot month and Austin temperatures
ax[1, 1].plot(austin_weather['MLY-CLDD-BASE45'], austin_weather['MLY-TAVG-NORMAL'])
plt.show()

# %%
# Create a figure and an array of axes: 2 rows, 1 column with shared y axis
fig, ax = plt.subplots(2, 1, sharey=True)

# Plot Seattle precipitation data in the top axes
ax[0].plot(seattle_weather['MLY-CLDD-BASE45'], seattle_weather['MLY-PRCP-NORMAL'], color = 'b')
ax[0].plot(seattle_weather['MLY-CLDD-BASE45'], seattle_weather['MLY-PRCP-25PCTL'], color = 'b', linestyle = '--')
ax[0].plot(seattle_weather['MLY-CLDD-BASE45'], seattle_weather['MLY-PRCP-75PCTL'], color = 'b', linestyle = '--')

# Plot Austin precipitation data in the bottom axes
ax[1].plot(austin_weather['MLY-CLDD-BASE45'], austin_weather['MLY-PRCP-NORMAL'], color = 'r')
ax[1].plot(austin_weather['MLY-CLDD-BASE45'], austin_weather['MLY-PRCP-25PCTL'], color = 'r', linestyle = '--')
ax[1].plot(austin_weather['MLY-CLDD-BASE45'], austin_weather['MLY-PRCP-75PCTL'], color = 'r', linestyle = '--')

plt.show()

# %%
# Import pandas as pd
import pandas as pd

# Read the data from file using read_csv
climate_change = pd.read_csv("climate_change.csv", parse_dates=True, index_col="date")

climate_change.head()
# Out:
#                co2  relative_temp
# date
# 1958-03-06  315.71           0.10
# 1958-04-06  317.45           0.01
# 1958-05-06  317.50           0.08
# 1958-06-06     NaN          -0.05
# 1958-07-06  315.86           0.06

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Add the time-series for "relative_temp" to the plot
ax.plot(climate_change.index, climate_change.relative_temp)

# Set the x-axis label
ax.set_xlabel("Time")

# Set the y-axis label
ax.set_ylabel("Relative temperature (Celsius)")

# Show the figure
plt.show()

# %%
# Use plt.subplots to create fig and ax
fig, ax = plt.subplots()

# Create variable seventies with data from "1970-01-01" to "1979-12-31"
seventies = climate_change["1970-01-01":"1979-12-31"]

# Add the time-series for "co2" data from seventies to the plot
ax.plot(seventies.index, seventies.co2)

# Show the figure
plt.show()

# %%
# Initalize a Figure and Axes
fig, ax = plt.subplots()

# Plot the CO2 variable in blue
ax.plot(climate_change.index, climate_change["co2"], color='b')

# Create a twin Axes that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature in red
ax2.plot(climate_change.index, climate_change["relative_temp"], color='r')

plt.show()

# %%
# Define a function called plot_timeseries to plot your graphs automatically
def plot_timeseries(axes, x, y, color, xlabel, ylabel):

  # Plot the inputs x,y in the provided color
  axes.plot(x, y, color=color)

  # Set the x-axis label
  axes.set_xlabel(xlabel)

  # Set the y-axis label
  axes.set_ylabel(ylabel, color=color)

  # Set the colors tick params for y-axis
  axes.tick_params('y', colors=color)

# %%
fig, ax = plt.subplots()

# Plot the CO2 levels time-series in blue
plot_timeseries(ax, climate_change.index, climate_change["co2"], "blue", "Time (years)", "CO2 levels")

# Create a twin Axes object that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature data in red
plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], "red", "Time (years)", "Relative temperature (Celsius)")

plt.show()

# %%
fig, ax = plt.subplots()

# Plot the relative temperature data
ax.plot(climate_change.index, climate_change["relative_temp"])

# Annotate the date at which temperatures exceeded 1 degree
ax.annotate(">1 degree", xy=[pd.Timestamp('2015-10-06'), 1])

plt.show()

# %%
fig, ax = plt.subplots()

# Plot the CO2 levels time-series in blue
plot_timeseries(ax, climate_change.index, climate_change["co2"], 'blue', "Time (years)","CO2 levels")

# Create an Axes object that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature data in red
plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], 'red', "Time (years)", "Relative temp (Celsius)")

# Annotate point with relative temperature >1 degree
ax2.annotate(">1 degree", xy=(pd.Timestamp('2015-10-06 00:00:00'), 1),xytext=(pd.Timestamp('2008-10-06 00:00:00'), -0.2),  arrowprops={'arrowstyle': '->', 'color': 'gray'})

plt.show()

# %%
# New DataFrame with countries as index:
medals = pd.read_csv("medals_by_country_2016.csv", index_col = 0)

fig, ax = plt.subplots()

# Plot a bar-chart of gold medals as a function of country
ax.bar(medals.index, medals["Gold"])

# Set the x-axis tick labels to the country names
ax.set_xticklabels(medals.index, rotation=90)

# Set the y-axis label
ax.set_ylabel("Number of medals")

plt.show()

# %%
fig, ax = plt.subplots()

# Add bars for "Gold" with the label "Gold"
ax.bar(medals.index, medals["Gold"], label="Gold")

# Stack bars for "Silver" on top with label "Silver"
ax.bar(medals.index, medals["Silver"], bottom=medals["Gold"], label="Silver")

# Stack bars for "Bronze" on top of that with label "Bronze"
ax.bar(medals.index, medals["Bronze"], bottom=medals["Silver"] + medals["Gold"], label="Bronze")

# Set the x-axis tick labels to the country names and rotate them to make the graph easier to read and understand
ax.set_xticklabels(medals.index, rotation=90)

# Display the legend
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

# Plot a histogram of "Weight" for mens_rowing
ax.hist(medals["Gold"])

# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(medals["Bronze"])

# Set the x-axis label to "Weight (kg)"
ax.set_xlabel("Medals")

# Set the y-axis label to "# of observations"
ax.set_ylabel("# of observations")

plt.show()

# %%
fig, ax = plt.subplots()

# Plot a histogram of "Weight" for mens_rowing
ax.hist(medals["Gold"], label="Medals Gold", histtype="step", bins=5)

# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(medals["Bronze"], label="Medals Bronze", histtype="step", bins=5)

ax.set_xlabel("Medals")
ax.set_ylabel("# of observations")

# Add the legend and show the Figure
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Add a bar for the rowing "Height" column mean/std
ax.bar("Medals Gold", medals["Gold"].mean(), yerr=medals["Gold"].std())

# Add a bar for the gymnastics "Height" column mean/std
ax.bar("Medals Bronze", medals["Bronze"].mean(), yerr=medals["Bronze"].std())

# Label the y-axis
ax.set_ylabel("Medals")

plt.show()

# %%
fig, ax = plt.subplots()

# Add the Seattle temperature data in each month with standard deviation error bars
ax.errorbar(seattle_weather["MLY-PRCP-AVGNDS-GE001HI"], seattle_weather["MLY-TAVG-NORMAL"], yerr=seattle_weather["MLY-TAVG-STDDEV"])

# Add the Austin temperature data in each month with standard deviation error bars
ax.errorbar(austin_weather["MLY-PRCP-AVGNDS-GE001HI"], austin_weather["MLY-TAVG-NORMAL"], yerr=austin_weather["MLY-TAVG-STDDEV"])

# Set the y-axis label
ax.set_ylabel("Temperature (Fahrenheit)")

plt.show()

# %%
# BOXPLOTS

fig, ax = plt.subplots()

# Add a boxplot for the "Height" column in the DataFrames
ax.boxplot([medals["Gold"], medals["Bronze"]])

# Add x-axis tick labels:
ax.set_xticklabels(["Gold", "Bronze"])

# Add a y-axis label
ax.set_ylabel("Medals")

plt.show()

# %%
# SCATTER PLOTS

climate_change = pd.read_csv("climate_change.csv")

fig, ax = plt.subplots()

# Add data: "co2" on x-axis, "relative_temp" on y-axis
ax.scatter(climate_change["co2"], climate_change["relative_temp"])

# Set the x-axis label to "CO2 (ppm)"
ax.set_xlabel("CO2 (ppm)")

# Set the y-axis label to "Relative temperature (C)"
ax.set_ylabel("Relative temperature (C)")

plt.show()

# %%
fig, ax = plt.subplots()

# Add data: "co2", "relative_temp" as x-y, index as color
ax.scatter(climate_change["co2"], climate_change["relative_temp"], c=climate_change.index)

# Set the x-axis label to "CO2 (ppm)"
ax.set_xlabel("CO2 (ppm)")

# Set the y-axis label to "Relative temperature (C)"
ax.set_ylabel("Relative temperature (C)")

plt.show()

# %%
# CHANGING THE STYLE OF A GRAPH

# Use the "ggplot" style and create new Figure/Axes
plt.style.use("ggplot")
fig, ax = plt.subplots()
ax.plot(btcUsd['High'])
plt.show()

# %%
# Use the "Solarize_Light2" style and create new Figure/Axes
plt.style.use("Solarize_Light2")
fig, ax = plt.subplots()
ax.plot(austin_weather["MLY-TMIN-PRBOCC-LSTH028"], austin_weather["MLY-TAVG-NORMAL"])
plt.show()

# %% [markdown]
# ## Save a figure as a PNG file:
#
#             - fig.savefig("my_figure.png")
#
# ## Save as a PNG file with 300 dpi; dpi is the resolution:
#
#             - fig.savefig("my_figure_300dpi.png", dpi=300)
#
# ## Set figure dimensions and save as a PNG:
#
#             - fig.set_size_inches([5, 3])    ----> This method takes a sequence of two values. The first sets the width
#                                                    and the second sets the height of the figure.
#             - fig.savefig("figure_5_3.png")

# %%
# Extracting unique values

summer_2016_medals = pd.read_csv("summer2016.csv")

# Extract the "Sport" column
sports_column = summer_2016_medals["Sport"]

# Find the unique values of the "Sport" column
sports = summer_2016_medals["Sport"].unique()

# Print out the unique sports values
print(sports)
# Out:
# ['Rowing' 'Taekwondo' 'Handball' 'Wrestling' 'Gymnastics' 'Swimming'
#  'Basketball' 'Boxing' 'Volleyball' 'Athletics' 'Rugby Sevens' 'Judo'
#  'Rhythmic Gymnastics' 'Weightlifting' 'Equestrianism' 'Badminton'
#  'Water Polo' 'Football' 'Fencing' 'Shooting' 'Sailing' 'Beach Volleyball'
#  'Canoeing' 'Hockey' 'Cycling' 'Tennis' 'Diving' 'Table Tennis'
#  'Triathlon' 'Archery' 'Synchronized Swimming' 'Modern Pentathlon'
#  'Trampolining' 'Golf']

# %%
fig, ax = plt.subplots()

# Loop over the different sports branches
for sport in sports:
  # Extract the rows only for this sport
  sport_df = summer_2016_medals[summer_2016_medals["Sport"] == sport]
  # Add a bar for the "Weight" mean with std y error bar
  ax.bar(sport, sport_df["Weight"].mean(), yerr=sport_df["Weight"].std())

ax.set_ylabel("Weight")
ax.set_xticklabels(sports, rotation=90)

plt.show()

# Save the figure to file
fig.savefig("sports_weights.png")
